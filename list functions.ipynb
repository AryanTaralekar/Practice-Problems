# %%
months=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
month_number=int(input("Enter month number (1-12):"))
if month_number >=1 and month_number<=12:
    print ("Month abbreviation:",months[month_number - 1])
else:
    print ("Invalid month number")
# Out:
# Enter month number (1-12): 2
# Month abbreviation: Feb

# %%
fruits=["apple","banana","orange","watermelon","cherry","strawberry","blueberry"]
fruits.remove("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'watermelon', 'cherry', 'strawberry', 'blueberry']

# %%
fruits=["apple","banana","orange","watermelon","cherry","strawberry","blueberry"]
removed_iten = fruits.pop(0)
print(fruits)
# Out:
# ['banana', 'orange', 'watermelon', 'cherry', 'strawberry', 'blueberry']

# %%
NO=[101,102,103,104]
Names=["Amit","Aryan","Rohit","Vedant"]
student_dict = dict(zip(NO,Names))
print("Dictionary",student_dict)
# Out:
# Dictionary {101: 'Amit', 102: 'Aryan', 103: 'Rohit', 104: 'Vedant'}

# %%
A=[1,2,3,3,4,5,5,6]
B=list(set(A))
print(B)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
L1=[10,20,30,40,50]
L2=[30,40,50,60,70]
common=[]
for elements in L1:
    if elements in L2:
        common.append(elements)
        print (common)
# Out:
# [30]
# [30, 40]
# [30, 40, 50]
